# %% [markdown]
# # Análisis de Datos de Fraude en Seguros de Auto

# %% [markdown]
# ## 1. Análisis Exploratorio de los Datos (EDA)

# %% [markdown]
# ### 1.1 Carga de Librerías

# %%
pip install pandas_visual_analysis
# Out:
# Collecting pandas_visual_analysis
#   Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl (34 kB)
# Collecting blinker>=1.4
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.19.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.21.5)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas_visual_analysis) (7.6.5)
# Requirement already satisfied: setuptools>=49.2.0 in c:\users\acer\anaconda3\lib\site-packages (from pandas_visual_analysis) (61.2.0)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\acer\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.4.2)
# Requirement already satisfied: plotly>=4.10.0 in c:\users\acer\anaconda3\lib\site-packages (from pandas_visual_analysis) (5.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (8.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\acer\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\acer\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\acer\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\acer\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\acer\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\acer\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: decorator in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.1)
# Requirement already satisfied: backcall in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.20)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\acer\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\acer\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\acer\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\acer\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\acer\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\acer\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\acer\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\acer\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\acer\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\acer\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (8.0.1)
# Requirement already satisfied: six in c:\users\acer\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\acer\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\acer\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.4)
# Requirement already satisfied: jinja2 in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\acer\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\acer\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\acer\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\acer\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\acer\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.1)
# Requirement already satisfied: bleach in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.11.1)
# Requirement already satisfied: testpath in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\acer\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\acer\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: packaging in c:\users\acer\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\acer\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.4)
# Requirement already satisfied: asttokens in c:\users\acer\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.5)
# Requirement already satisfied: executing in c:\users\acer\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\acer\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.2)
# Installing collected packages: blinker, pandas-visual-analysis
# Successfully installed blinker-1.5 pandas-visual-analysis-0.0.4

# %%
# Cargamos las librerías a utilizar
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_visual_analysis import VisualAnalysis

# %% [markdown]
# ### 1.2 Carga de Datos

# %%
# Nombramos el dataframe
car_fraud = pd.read_csv('.\..\data\Dataset.csv')

# Mostramos un encabezado de los datos
car_fraud.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Feb            1   Saturday   Honda        Urban           Monday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# 0          Jan                   1  Female        Single  ...
# 1          Jan                   4    Male        Single  ...
# 2          Nov                   2    Male       Married  ...
# 3          Jul                   1    Male       Married  ...
# 4          Feb                   3    Male       Married  ...
#
#    AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0           26 to 30                No             No  External
# 1           31 to 35               Yes             No  External
# 2           41 to 50                No             No  External
# 3           51 to 65               Yes             No  External
# 4           36 to 40                No             No  External
#
#   NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy  \
# 0                none               1 year        3 to 4  1994   Liability
# 1                none            no change     1 vehicle  1994   Collision
# 2                none            no change     1 vehicle  1994   Collision
# 3         more than 5            no change     1 vehicle  1994   Liability
# 4              1 to 2            no change     1 vehicle  1994   Collision
#
#       ClaimSize
# 0  55526.069420
# 1  59294.455570
# 2  71756.941320
# 3   7584.153493
# 4  98545.374340
#
# [5 rows x 34 columns]

# %%
VisualAnalysis(car_fraud)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-fea589a705db4cbe84822c2da00d6544',), description='Selection…

# %%
# Mostramos el número de filas, columnas, valores NO nulos y el tipo de datos
car_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11565 entries, 0 to 11564
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 11565 non-null  object
#  1   WeekOfMonth           11565 non-null  int64
#  2   DayOfWeek             11565 non-null  object
#  3   Make                  11565 non-null  object
#  4   AccidentArea          11565 non-null  object
#  5   DayOfWeekClaimed      11565 non-null  object
#  6   MonthClaimed          11565 non-null  object
#  7   WeekOfMonthClaimed    11565 non-null  int64
#  8   Sex                   11565 non-null  object
#  9   MaritalStatus         11565 non-null  object
#  10  Age                   11560 non-null  float64
#  11  Fault                 11565 non-null  object
#  12  PolicyType            11565 non-null  object
#  13  VehicleCategory       11565 non-null  object
#  14  VehiclePrice          11565 non-null  object
#  15  FraudFound_P          11565 non-null  int64
#  16  PolicyNumber          11565 non-null  int64
#  17  RepNumber             11565 non-null  int64
#  18  Deductible            11565 non-null  int64
#  19  DriverRating          11559 non-null  float64
#  20  Days_Policy_Accident  11565 non-null  object
#  21  Days_Policy_Claim     11565 non-null  object
#  22  PastNumberOfClaims    11565 non-null  object
#  23  AgeOfVehicle          11565 non-null  object
#  24  AgeOfPolicyHolder     11565 non-null  object
#  25  PoliceReportFiled     11565 non-null  object
#  26  WitnessPresent        11565 non-null  object
#  27  AgentType             11565 non-null  object
#  28  NumberOfSuppliments   11565 non-null  object
#  29  AddressChange_Claim   11565 non-null  object
#  30  NumberOfCars          11565 non-null  object
#  31  Year                  11565 non-null  int64
#  32  BasePolicy            11565 non-null  object
#  33  ClaimSize             11565 non-null  float64
# dtypes: float64(3), int64(7), object(24)
# memory usage: 3.0+ MB

# %% [markdown]
# ### 1.3 Estadística Descriptiva

# %%
# Resumimos las variables numéricas
car_fraud.describe().T.round(2)
# Out:
#                       count      mean       std     min      25%      50%  \
# WeekOfMonth         11565.0      2.78      1.28     1.0     2.00     3.00
# WeekOfMonthClaimed  11565.0      2.70      1.26     1.0     2.00     3.00
# Age                 11560.0     39.90     13.59     0.0    31.00    38.00
# FraudFound_P        11565.0      0.06      0.24     0.0     0.00     0.00
# PolicyNumber        11565.0   7710.47   4453.76     1.0  3851.00  7712.00
# RepNumber           11565.0      8.47      4.62     1.0     4.00     8.00
# Deductible          11565.0    407.62     43.40   300.0   400.00   400.00
# DriverRating        11559.0      2.49      1.12     1.0     1.00     3.00
# Year                11565.0   1994.87      0.80  1994.0  1994.00  1995.00
# ClaimSize           11565.0  22955.98  26988.81     0.0  4148.85  8130.99
#
#                          75%        max
# WeekOfMonth             4.00       5.00
# WeekOfMonthClaimed      4.00       5.00
# Age                    49.00      80.00
# FraudFound_P            0.00       1.00
# PolicyNumber        11542.00   15420.00
# RepNumber              12.00      16.00
# Deductible            400.00     700.00
# DriverRating            3.00       4.00
# Year                 1996.00    1996.00
# ClaimSize           46299.65  141394.16

# %%
# Resuminos las variables categóricas
car_fraud.describe(include = ['O']).T
# Out:
#                       count unique                top   freq
# Month                 11565     12                Jan   1056
# DayOfWeek             11565      7             Monday   2000
# Make                  11565     19            Pontiac   2899
# AccidentArea          11565      2              Urban  10356
# DayOfWeekClaimed      11565      8             Monday   2811
# MonthClaimed          11565     13                Jan   1084
# Sex                   11565      2               Male   9768
# MaritalStatus         11565      4            Married   7986
# Fault                 11565      2      Policy Holder   8394
# PolicyType            11565      9  Sedan - Collision   4186
# VehicleCategory       11565      3              Sedan   7253
# VehiclePrice          11565      6     20000 to 29000   6112
# Days_Policy_Accident  11565      5       more than 30  11439
# Days_Policy_Claim     11565      4       more than 30  11504
# PastNumberOfClaims    11565      4             2 to 4   4140
# AgeOfVehicle          11565      8            7 years   4388
# AgeOfPolicyHolder     11565      9           31 to 35   4199
# PoliceReportFiled     11565      2                 No  11235
# WitnessPresent        11565      2                 No  11497
# AgentType             11565      2           External  11394
# NumberOfSuppliments   11565      4               none   5330
# AddressChange_Claim   11565      5          no change  10715
# NumberOfCars          11565      5          1 vehicle  10698
# BasePolicy            11565      3          Collision   4472

# %% [markdown]
# ### 1.4 Visualización Univariable

# %%
# Trazamos los histogramas
car_fraud.hist(bins=10 , figsize=(10,10)) 
plt.show()

# %%
# Trazamos las gráficas de densidad
car_fraud.plot(kind = 'density', subplots = True, layout = (4,3), sharex = False, figsize=(10,10))
plt.show()

# %%
# Trazamos los gráficos de caja o boxplot
#sns.set_style("darkgrid")
car_fraud.plot(kind = 'box', subplots = True, layout = (4,3), sharex = False, figsize=(10,10))
plt.show()

# %% [markdown]
# ### 1.5 Visualización Multivariable

# %%
# Diagrama de dispersión
# diag_kind = 'hist'
sns.pairplot(car_fraud, hue = 'FraudFound_P')
plt.show()

# %%
# Boxplot por clase

# %% [markdown]
# ### 1.6 Análisis de la Variable Objetivo

# %%
# Proporción del fraude respecto al total de reclamaciones
car_fraud.groupby('FraudFound_P').size()
# Out:
# FraudFound_P
# 0    10880
# 1      685
# dtype: int64

# %%
grouped_fraud = car_fraud.groupby('FraudFound_P').count()
grouped_fraud = grouped_fraud['PolicyNumber'].reset_index()
plt.pie(grouped_fraud['PolicyNumber'], autopct='%1.0f%%', labels = grouped_fraud['FraudFound_P'])
plt.show()

# %% [markdown]
# #### 1.6.1 Visualización de Variables Categóricas

# %%
# Cómo se distribuye el fraude por sexo del asegurado
car_fraud.groupby(['FraudFound_P', 'Sex']).count()['PolicyNumber']
# Out:
# FraudFound_P  Sex
# 0             Female    1724
#               Male      9156
# 1             Female      73
#               Male       612
# Name: PolicyNumber, dtype: int64

# %%
grouped_sex = car_fraud.groupby(['FraudFound_P', 'Sex']).count()['PolicyNumber']
grouped_sex.unstack(level=0).plot.bar()
plt.show()

# %%
# Cómo se distribuye el fraude por reporte policial
car_fraud.groupby(['FraudFound_P', 'PoliceReportFiled']).count()['PolicyNumber']
# Out:
# FraudFound_P  PoliceReportFiled
# 0             No                   10563
#               Yes                    317
# 1             No                     672
#               Yes                     13
# Name: PolicyNumber, dtype: int64

# %%
grouped_sex = car_fraud.groupby(['FraudFound_P', 'PoliceReportFiled']).count()['PolicyNumber']
grouped_sex.unstack(level=0).plot.bar()
plt.show()

# %%
# Cómo se distribuye el fraude por testigo presente
car_fraud.groupby(['FraudFound_P', 'WitnessPresent']).count()['PolicyNumber']
# Out:
# FraudFound_P  WitnessPresent
# 0             No                10814
#               Yes                  66
# 1             No                  683
#               Yes                   2
# Name: PolicyNumber, dtype: int64

# %%
grouped_sex = car_fraud.groupby(['FraudFound_P', 'WitnessPresent']).count()['PolicyNumber']
grouped_sex.unstack(level=0).plot.bar()
plt.show()

# %% [markdown]
# #### 1.6.2 Visualización de Variables Numéricas

# %%
# Creamos un dataframe solo para fraude encontrado
fraud_found = car_fraud[car_fraud['FraudFound_P'] == 1]
fraud_found.shape
# Out:
# (685, 34)

# %%
# Cómo se distribuye el fraude por edad del asegurado
fraud_found['Age'].plot.hist()
plt.ylabel('Frecuency')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
# Cómo se distribuye el fraude por tamaño de la reclamación
fraud_found['ClaimSize'].plot.hist()
plt.ylabel('Frecuency')
plt.xlabel('ClaimSize')
# Out:
# Text(0.5, 0, 'ClaimSize')
